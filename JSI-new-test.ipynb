# %%
print("hello world")
# Out:
# hello world

# %%
# %matplotlib inline
import matplotlib.pyplot as pit
import numpy as np
pit.plot(np.random.randn(200).cumsum())
pit.plot([1,2,3,4,-2,0,2,3,33,3,2,4])

# %%
# %run hello_world.py
# Out:
# hello world
